# %%
import matplotlib.pyplot as plt

# %%
def create_image(rgb_img,h1,w1,h2,w2,ans):
    crop_img111 = "patch" + "041_" + ans
    crop_img1 = crop_img111 + ".png"
    crop_img11 = rgb_img[h1:h2, w1:w2]
    plt.figure()
    plt.imshow(crop_img11)
    #print(crop_img11.shape)
    cv2.imwrite(crop_img1, crop_img11)

# %%
import cv2

# %%
img = cv2.imread("./diaretdb1_v_1_1/resources/images/ddb1_fundusimages/image041.png")

# %%
#cv2.imshow('image',img)
b,g,r = cv2.split(img)       # get b,g,r
rgb_img = cv2.merge([r,g,b])
r_img = cv2.merge([r])
#g_img = cv2.merge([g])
# switch it to rgb

# %%
plt.figure()
plt.imshow(rgb_img)
plt.figure()
plt.imshow(r_img)

# %%
h,w = r_img.shape
#print(h)
#print(w)

# %%
count = 0
for i in range(0,w,250):
    for j in range(0,h,250):
        h1 = j
        h2 = j+250
        #print(h1)
        #print(h2)
        w1 = i
        w2 = i+250
        #print(w1)
        #print(w2)
        #print(h1)
        #print(h2)
        create_image(r_img,h1,w1,h2,w2,str(count))
        count+=1
#print(count)
# Out:
# C:\Users\Hardik Rana\AppData\Roaming\Python\Python36\site-packages\matplotlib\pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
